# %%
# %load_ext autoreload
# %autoreload 2
import os
os.chdir('../')

# %%
from utils.metrics import *

# %%
step_size = 3
steps = 6
resample_traj_steps = np.arange(1,(steps*step_size)+1, step_size)

plot_results('results_tfreq_exp_wnoise_seed', x='Temporal Sparsity Interval', xlabels=resample_traj_steps, xlabel='Resampling Interval', results_folder='./old_experimental_results_4')

# %%
n_traj_steps = [7535, 15070, 22605, 30140, 37676]
x_labels = [f'{n_traj}' for n_traj in n_traj_steps]
plot_results(folder_prefix=f'results_sparsity_exp_wnoise_seed', x='Sparsity', xlabels=x_labels, xlabel='# of trajectories', results_folder='./old_experimental_results_4')
# Out:
# [0.05357329 0.02025439 0.02346964 0.02312557 0.        ]
# [3.80455242e-02 1.36560806e-02 2.18129736e-02 4.74051882e-03
#  5.55111512e-17]

# %%
from SHDataset import SHDataset

bbox = (52.335, 52.36, 4.89, 4.92)
dataset = SHDataset(noise=True, noise_config=1)
G1,T1,G2,T2 = dataset.read_snapshots(0, bbox)
# Out:
# ...
# Adding noise to trajectories: 100%|███████████████████████████████████████████████████████████████████████████████████████████| 37327/37327 [00:17<00:00, 2081.50it/s]

# %%
from utils.utils import *
import random
plot_graph(snapshot_to_nxgraph(G1,random.sample(T2['T'], 1000)))

# %%
from SHDataset import SHDataset

dataset = SHDataset(noise=True, noise_config=1, resample_timedp=True, resample_everyn=4)

# %%
bbox = (52.335, 52.36, 4.89, 4.92)
dataset.read_snapshots(0, bbox=bbox)
# Out:
# Adding noise to trajectories:   0%|▏                                                                                              | 92/37659 [00:00<00:08, 4277.58it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [4], in <cell line: 2>()
#       1 bbox = (52.335, 52.36, 4.89, 4.92)
# ----> 2 dataset.read_snapshots(0, bbox=bbox)
#
# File /media/deepstorage01/home2/waller/SyntheticHighways/ChangeDetection/SHDataset.py:223, in SHDataset.read_snapshots(self, i, bbox)
#     220     T2['T'] = self.resample_timedpoints(T2['T'])
#     222 if self.noise:
# --> 223     T1['T'] = self.add_noise_parallel(T1['T'])
#     224     T2['T'] = self.add_noise_parallel(T2['T'])
#     226 return G1,T1,G2,T2
#
# File /media/deepstorage01/home2/waller/SyntheticHighways/ChangeDetection/SHDataset.py:555, in SHDataset.add_noise_parallel(self, T)
# ...
