# %%
# %load_ext autoreload
# %autoreload 2
import os
os.chdir('../')

# %%
from SHDataset import SHDataset
from utils import *

# %%
dataset = SHDataset(noise=False, resample_timedp=False)
G1,T1,G2,T2 = dataset.read_snapshots(0, bbox=(52.34, 52.35, 4.89, 4.93))

# %%
def resample(t, step=1):
    return t[0:-1:step]

i = 0
t = T1['T'][i]

plot_graph(snapshot_to_nxgraph(G1, [t]), show_nodes=True, zoom_on_traj=True)
plot_graph(snapshot_to_nxgraph(G1, [resample(t, step=2)]), show_nodes=True, zoom_on_traj=True)
plot_graph(snapshot_to_nxgraph(G1, [resample(t, step=3)]), show_nodes=True, zoom_on_traj=True)
plot_graph(snapshot_to_nxgraph(G1, [resample(t, step=4)]), show_nodes=True, zoom_on_traj=True)
plot_graph(snapshot_to_nxgraph(G1, [resample(t, step=5)]), show_nodes=True, zoom_on_traj=True)

# %%
dataset = SHDataset(noise=False, resample_timedp=True, resample_everyn=3)
G1,T1,G2,T2 = dataset.read_snapshots(0, bbox=(52.34, 52.35, 4.89, 4.93))

# %%
plot_graph(snapshot_to_nxgraph(G1,T2['T']), figsize=(10,10))
